# %%
import os

# %% [markdown]
# **WORKING DIRECTORY**

# %%
print(os.getcwd())  # Get current working directory

# %%
os.chdir(r"C:\Users\actor\Desktop\Python")  # Change to /tmp directory
print(os.getcwd())  # Verify the change

# %%
os.listdir()

# %% [markdown]
# **SAFE PATH HANDLING**

# %%
data_path = os.path.join(os.getcwd(), "MOdules_in_python")  # Safe path joining
print(data_path)  # Safe path handling

# %%
os.path.getsize(r"C:\Users\actor\Desktop\Video Resources")  # Get size of the path in bytes

# %% [markdown]
# **FILE EXISTS?**

# %%
if not os.path.exists("sys"):
    os.mkdir("sys")  # Create directory if it doesn't exist

# %%
os.rmdir("sys")  # Remove the directory

# %%
# Create nested directories recursively
os.makedirs("parent/child/grandchild")

# %%
# Create directories with specific permissions and ignore if it exists
os.makedirs("parent/child", mode=0o755, exist_ok=True)

# %% [markdown]
# **ENVIRONMENT VARIABLES**

# %%
api_key = os.getenv("API_KEY")
print(f"API Key: {api_key}")

# %% [markdown]
# **RENAME OR DELETE FILES**

# %%
os.rename("parent", "new_parent")  # Rename directory

# %%
os.remove(r"C:\Users\actor\Desktop\Python\Modules_in_python\temp.txt")  # Remove files

# %% [markdown]
# **SYSTEM**

# %%
os.system("echo Hello, World!")  # Execute a system command but

# %%
print(os.system(r"C:\Users\actor\Desktop\Python"))  # List directory contents (Windows)

# %%
os.startfile(r"C:\Users\actor\Desktop\Python\Modules_in_python\temp.txt")  # Open file with default application
