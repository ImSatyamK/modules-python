# %%
import sys

# %% [markdown]
# **COMMAND LINE ARGUMENTS**

# %%
print(sys.argv) #refer to print_args.py to understand
# Out:
# ['c:\\Users\\actor\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\ipykernel_launcher.py', '--f=c:\\Users\\actor\\AppData\\Roaming\\jupyter\\runtime\\kernel-v33e8765320cb22734487ce54cf500ca8681dbfa9e.json']

# %% [markdown]
# **EXITING A PROGRAM**

# %%
if 2 < 3:
    sys.exit("❌ Critical error — stopping program")

# Refer to sys_exit.py to understand
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: ❌ Critical error — stopping program
