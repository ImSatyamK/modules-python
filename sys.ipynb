# %%
import sys

# %% [markdown]
# **COMMAND LINE ARGUMENTS**

# %%
print(sys.argv) #refer to print_args.py to understand
# Out:
# ['c:\\Users\\actor\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\ipykernel_launcher.py', '--f=c:\\Users\\actor\\AppData\\Roaming\\jupyter\\runtime\\kernel-v351bb85329fe51ab8585ca52d9efd902d7653b4c3.json']

# %% [markdown]
# **EXITING A PROGRAM**

# %%
if 2 < 3:
    sys.exit("❌ Critical error — stopping program")

# Refer to sys_exit.py to understand
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: ❌ Critical error — stopping program
# c:\Users\actor\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py:3707: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# **STANDARD INPUT/OUTPUT/ERROR STREAMS**

# %%
sys.stdout.write("This prints normally")
# Out:
# This prints normally
# 20

# %%
sys.stderr.write("This is an error message")
# Out:
# This is an error message
# 24

# %%
print('Enter something: ')
text = sys.stdin.readline()
print('you entered: ', text)

# Run in a .py file
# Out:
# Enter something:
